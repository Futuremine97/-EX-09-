# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-1317-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person299_bacteria_1418.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1072
# Pneumonia images count in training set: 3113

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
# def augment(image,label):
#     image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
#     return image,label

# def prepare_for_training(ds, shuffle_buffer_size=1000):
#     # augment 적용 부분이 배치처리 함수에 추가되었습니다.
#     ds = ds.map(
#             augment,       # augment 함수 적용
#             num_parallel_calls=2
#         )
#     ds = ds.shuffle(buffer_size=shuffle_buffer_size)
#     ds = ds.repeat()
#     ds = ds.batch(BATCH_SIZE)
#     ds = ds.prefetch(buffer_size=AUTOTUNE)

#     return ds

# train_ds = prepare_for_training(train_ds)
# val_ds = prepare_for_training(val_ds)

def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='tanh'),#relu-->tanh
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNEUMONIA: 0.67

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 58s 190ms/step - loss: 0.3197 - accuracy: 0.8496 - precision: 0.9679 - recall: 0.8251 - val_loss: 1.5814 - val_accuracy: 0.7365 - val_precision: 0.7365 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 48s 186ms/step - loss: 0.2627 - accuracy: 0.8834 - precision: 0.9716 - recall: 0.8688 - val_loss: 1.8536 - val_accuracy: 0.7365 - val_precision: 0.7365 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 48s 186ms/step - loss: 0.2124 - accuracy: 0.9073 - precision: 0.9789 - recall: 0.8947 - val_loss: 0.2581 - val_accuracy: 0.9087 - val_precision: 0.9941 - val_recall: 0.8810
# Epoch 4/25
# 261/261 [==============================] - 49s 187ms/step - loss: 0.2103 - accuracy: 0.9181 - precision: 0.9792 - recall: 0.9091 - val_loss: 0.2856 - val_accuracy: 0.9096 - val_precision: 0.9927 - val_recall: 0.8837
# Epoch 5/25
# 261/261 [==============================] - 49s 189ms/step - loss: 0.1785 - accuracy: 0.9262 - precision: 0.9811 - recall: 0.9186 - val_loss: 1.0660 - val_accuracy: 0.7365 - val_precision: 0.7365 - val_recall: 1.0000
# Epoch 6/25
# 261/261 [==============================] - 50s 193ms/step - loss: 0.1741 - accuracy: 0.9267 - precision: 0.9821 - recall: 0.9183 - val_loss: 0.0840 - val_accuracy: 0.9731 - val_precision: 0.9767 - val_recall: 0.9869
# Epoch 7/25
# 261/261 [==============================] - 54s 207ms/step - loss: 0.1560 - accuracy: 0.9404 - precision: 0.9815 - recall: 0.9376 - val_loss: 0.1373 - val_accuracy: 0.9538 - val_precision: 0.9959 - val_recall: 0.9412
# Epoch 8/25
# 261/261 [==============================] - 46s 177ms/step - loss: 0.1711 - accuracy: 0.9318 - precision: 0.9786 - recall: 0.9284 - val_loss: 0.4078 - val_accuracy: 0.8404 - val_precision: 0.8224 - val_recall: 0.9987
# Epoch 9/25
# 261/261 [==============================] - 46s 178ms/step - loss: 0.1777 - accuracy: 0.9274 - precision: 0.9814 - recall: 0.9198 - val_loss: 0.2733 - val_accuracy: 0.9163 - val_precision: 1.0000 - val_recall: 0.8863
# Epoch 10/25
# 261/261 [==============================] - 45s 172ms/step - loss: 0.1941 - accuracy: 0.9219 - precision: 0.9774 - recall: 0.9165 - val_loss: 0.0908 - val_accuracy: 0.9644 - val_precision: 0.9814 - val_recall: 0.9699
# Epoch 11/25
# 261/261 [==============================] - 47s 179ms/step - loss: 0.2163 - accuracy: 0.9155 - precision: 0.9718 - recall: 0.9126 - val_loss: 0.1649 - val_accuracy: 0.9337 - val_precision: 0.9295 - val_recall: 0.9843
# Epoch 12/25
# 261/261 [==============================] - 47s 181ms/step - loss: 0.2715 - accuracy: 0.8793 - precision: 0.9683 - recall: 0.8660 - val_loss: 0.6866 - val_accuracy: 0.6827 - val_precision: 0.9977 - val_recall: 0.5705
# Epoch 13/25
# 261/261 [==============================] - 46s 177ms/step - loss: 0.2588 - accuracy: 0.8860 - precision: 0.9680 - recall: 0.8759 - val_loss: 0.6089 - val_accuracy: 0.7375 - val_precision: 0.7380 - val_recall: 0.9987
# Epoch 14/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.2762 - accuracy: 0.8810 - precision: 0.9745 - recall: 0.8622 - val_loss: 0.3412 - val_accuracy: 0.8644 - val_precision: 0.9952 - val_recall: 0.8194
# Epoch 15/25
# 261/261 [==============================] - 46s 176ms/step - loss: 0.2684 - accuracy: 0.8805 - precision: 0.9698 - recall: 0.8669 - val_loss: 0.1700 - val_accuracy: 0.9346 - val_precision: 0.9820 - val_recall: 0.9280
# Epoch 16/25
# 261/261 [==============================] - 47s 181ms/step - loss: 0.2509 - accuracy: 0.8915 - precision: 0.9745 - recall: 0.8768 - val_loss: 0.1872 - val_accuracy: 0.9365 - val_precision: 0.9929 - val_recall: 0.9201
# Epoch 17/25
# 261/261 [==============================] - 46s 177ms/step - loss: 0.2387 - accuracy: 0.8898 - precision: 0.9741 - recall: 0.8749 - val_loss: 0.1349 - val_accuracy: 0.9538 - val_precision: 0.9931 - val_recall: 0.9439
# Epoch 18/25
# 261/261 [==============================] - 47s 179ms/step - loss: 0.2641 - accuracy: 0.8791 - precision: 0.9732 - recall: 0.8617 - val_loss: 0.7060 - val_accuracy: 0.7231 - val_precision: 1.0000 - val_recall: 0.6235
# Epoch 19/25
# 261/261 [==============================] - 45s 173ms/step - loss: 0.2455 - accuracy: 0.8908 - precision: 0.9790 - recall: 0.8719 - val_loss: 0.2613 - val_accuracy: 0.9000 - val_precision: 0.9985 - val_recall: 0.8652
# Epoch 20/25
# 261/261 [==============================] - 47s 179ms/step - loss: 0.2279 - accuracy: 0.9045 - precision: 0.9741 - recall: 0.8954 - val_loss: 0.2182 - val_accuracy: 0.9298 - val_precision: 0.9901 - val_recall: 0.9140
# Epoch 21/25
# 261/261 [==============================] - 46s 177ms/step - loss: 0.1984 - accuracy: 0.9188 - precision: 0.9792 - recall: 0.9100 - val_loss: 0.1308 - val_accuracy: 0.9529 - val_precision: 0.9864 - val_recall: 0.9490
# Epoch 22/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.2288 - accuracy: 0.9100 - precision: 0.9739 - recall: 0.9030 - val_loss: 0.1823 - val_accuracy: 0.9279 - val_precision: 0.9302 - val_recall: 0.9752
# Epoch 23/25
# 261/261 [==============================] - 47s 179ms/step - loss: 0.2539 - accuracy: 0.8961 - precision: 0.9705 - recall: 0.8876 - val_loss: 0.1273 - val_accuracy: 0.9500 - val_precision: 0.9837 - val_recall: 0.9476
# Epoch 24/25
# 261/261 [==============================] - 46s 176ms/step - loss: 0.2422 - accuracy: 0.9001 - precision: 0.9691 - recall: 0.8947 - val_loss: 0.1081 - val_accuracy: 0.9548 - val_precision: 0.9878 - val_recall: 0.9503
# Epoch 25/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.2312 - accuracy: 0.8989 - precision: 0.9762 - recall: 0.8858 - val_loss: 0.1693 - val_accuracy: 0.9337 - val_precision: 0.9957 - val_recall: 0.9138

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rotation_range = 20,#몸이 좀 틀어진경우(각도?자세?) 
                            horizontal_flip = True,
                            featurewise_std_normalization=True,
                            samplewise_std_normalization=True)
model.fit_generator(datagen.flow(image_batch, label_batch,batch_size=16),steps_per_epoch =len(image_batch)//16,  epochs = 25)
# Out:
# Epoch 1/25
# 1/1 [==============================] - 0s 190ms/step - loss: 0.2267 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9167
# Epoch 2/25
# 1/1 [==============================] - 0s 194ms/step - loss: 0.1695 - accuracy: 0.8750 - precision: 1.0000 - recall: 0.8333
# Epoch 3/25
# 1/1 [==============================] - 0s 192ms/step - loss: 0.3522 - accuracy: 0.8750 - precision: 1.0000 - recall: 0.8333
# Epoch 4/25
# 1/1 [==============================] - 0s 188ms/step - loss: 0.1734 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9167
# Epoch 5/25
# 1/1 [==============================] - 0s 189ms/step - loss: 0.2991 - accuracy: 0.8125 - precision: 1.0000 - recall: 0.7500
# Epoch 6/25
# 1/1 [==============================] - 0s 188ms/step - loss: 0.2865 - accuracy: 0.8125 - precision: 1.0000 - recall: 0.7500
# Epoch 7/25
# 1/1 [==============================] - 0s 196ms/step - loss: 0.1735 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9167
# Epoch 8/25
# 1/1 [==============================] - 0s 184ms/step - loss: 0.2026 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 9/25
# 1/1 [==============================] - 0s 193ms/step - loss: 0.2161 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9167
# Epoch 10/25
# 1/1 [==============================] - 0s 179ms/step - loss: 0.1026 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9167
# Epoch 11/25
# 1/1 [==============================] - 0s 184ms/step - loss: 0.1478 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9167
# Epoch 12/25
# 1/1 [==============================] - 0s 192ms/step - loss: 0.2851 - accuracy: 0.8125 - precision: 1.0000 - recall: 0.7500
# Epoch 13/25
# 1/1 [==============================] - 0s 193ms/step - loss: 0.2845 - accuracy: 0.8125 - precision: 1.0000 - recall: 0.7500
# Epoch 14/25
# 1/1 [==============================] - 0s 179ms/step - loss: 0.3074 - accuracy: 0.8750 - precision: 1.0000 - recall: 0.8333
# Epoch 15/25
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0870 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 16/25
# 1/1 [==============================] - 0s 180ms/step - loss: 0.2676 - accuracy: 0.8750 - precision: 1.0000 - recall: 0.8333
# Epoch 17/25
# 1/1 [==============================] - 0s 190ms/step - loss: 0.0636 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 18/25
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0465 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 19/25
# 1/1 [==============================] - 0s 184ms/step - loss: 0.1165 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 20/25
# 1/1 [==============================] - 0s 190ms/step - loss: 0.1508 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9167
# Epoch 21/25
# 1/1 [==============================] - 0s 182ms/step - loss: 0.1007 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9167
# Epoch 22/25
# 1/1 [==============================] - 0s 190ms/step - loss: 0.1119 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9167
# Epoch 23/25
# 1/1 [==============================] - 0s 182ms/step - loss: 0.0948 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 24/25
# 1/1 [==============================] - 0s 188ms/step - loss: 0.1262 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9167
# Epoch 25/25
# 1/1 [==============================] - 0s 184ms/step - loss: 0.0934 - accuracy: 0.9375 - precision: 1.0000 - recall: 0.9167

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 4s 105ms/step - loss: 0.4522 - accuracy: 0.8413 - precision: 0.8299 - recall: 0.9385
# Loss: 0.45218297839164734,
# Accuracy: 0.8413461446762085,
# Precision: 0.8299319744110107,
# Recall: 0.9384615421295166
