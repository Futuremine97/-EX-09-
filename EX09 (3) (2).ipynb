# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-1317-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person299_bacteria_1418.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1072
# Pneumonia images count in training set: 3113

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
# def augment(image,label):
#     image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
#     return image,label

# def prepare_for_training(ds, shuffle_buffer_size=1000):
#     # augment 적용 부분이 배치처리 함수에 추가되었습니다.
#     ds = ds.map(
#             augment,       # augment 함수 적용
#             num_parallel_calls=2
#         )
#     ds = ds.shuffle(buffer_size=shuffle_buffer_size)
#     ds = ds.repeat()
#     ds = ds.batch(BATCH_SIZE)
#     ds = ds.prefetch(buffer_size=AUTOTUNE)

#     return ds

# train_ds = prepare_for_training(train_ds)
# val_ds = prepare_for_training(val_ds)

def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='tanh'),#relu-->tanh
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(256, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNEUMONIA: 0.67

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rotation_range = 10,#몸이 좀 틀어진경우(각도?자세?) 
                            horizontal_flip = True,
                            featurewise_std_normalization=True,
                            samplewise_std_normalization=True)
model.fit_generator(datagen.flow(image_batch, label_batch,batch_size=16),steps_per_epoch =len(image_batch)//16,  epochs = 45)
# Out:
# Epoch 1/45
# 1/1 [==============================] - 6s 6s/step - loss: 0.6874 - accuracy: 0.7500 - precision: 1.0000 - recall: 0.6923
# Epoch 2/45
# 1/1 [==============================] - 0s 178ms/step - loss: 0.9537 - accuracy: 0.5625 - precision: 0.8750 - recall: 0.5385
# Epoch 3/45
# 1/1 [==============================] - 0s 180ms/step - loss: 1.3439 - accuracy: 0.3750 - precision: 0.7143 - recall: 0.3846
# Epoch 4/45
# 1/1 [==============================] - 0s 175ms/step - loss: 1.4208 - accuracy: 0.5000 - precision: 0.7778 - recall: 0.5385
# Epoch 5/45
# 1/1 [==============================] - 0s 178ms/step - loss: 0.8981 - accuracy: 0.5625 - precision: 0.8000 - recall: 0.6154
# Epoch 6/45
# 1/1 [==============================] - 0s 176ms/step - loss: 1.2112 - accuracy: 0.4375 - precision: 0.7000 - recall: 0.5385
# Epoch 7/45
# 1/1 [==============================] - 0s 179ms/step - loss: 0.9861 - accuracy: 0.3750 - precision: 0.7143 - recall: 0.3846
# Epoch 8/45
# 1/1 [==============================] - 0s 169ms/step - loss: 0.7918 - accuracy: 0.6250 - precision: 0.8889 - recall: 0.6154
# Epoch 9/45
# 1/1 [==============================] - 0s 182ms/step - loss: 1.2188 - accuracy: 0.5625 - precision: 0.8750 - recall: 0.5385
# Epoch 10/45
# 1/1 [==============================] - 0s 181ms/step - loss: 0.8791 - accuracy: 0.6250 - precision: 1.0000 - recall: 0.5385
# Epoch 11/45
# 1/1 [==============================] - 0s 191ms/step - loss: 0.8765 - accuracy: 0.5000 - precision: 0.8571 - recall: 0.4615
# Epoch 12/45
# 1/1 [==============================] - 0s 177ms/step - loss: 1.0036 - accuracy: 0.5625 - precision: 0.8750 - recall: 0.5385
# Epoch 13/45
# 1/1 [==============================] - 0s 188ms/step - loss: 1.2052 - accuracy: 0.6250 - precision: 0.8182 - recall: 0.6923
# Epoch 14/45
# 1/1 [==============================] - 0s 190ms/step - loss: 0.9101 - accuracy: 0.5625 - precision: 0.8000 - recall: 0.6154
# Epoch 15/45
# 1/1 [==============================] - 0s 186ms/step - loss: 0.8749 - accuracy: 0.6250 - precision: 0.8182 - recall: 0.6923
# Epoch 16/45
# 1/1 [==============================] - 0s 185ms/step - loss: 1.0489 - accuracy: 0.5625 - precision: 0.8750 - recall: 0.5385
# Epoch 17/45
# 1/1 [==============================] - 0s 187ms/step - loss: 1.1062 - accuracy: 0.5625 - precision: 0.8000 - recall: 0.6154
# Epoch 18/45
# 1/1 [==============================] - 0s 173ms/step - loss: 0.8533 - accuracy: 0.6250 - precision: 0.8182 - recall: 0.6923
# Epoch 19/45
# 1/1 [==============================] - 0s 191ms/step - loss: 0.9789 - accuracy: 0.3750 - precision: 0.8000 - recall: 0.3077
# Epoch 20/45
# 1/1 [==============================] - 0s 176ms/step - loss: 1.0151 - accuracy: 0.4375 - precision: 0.7500 - recall: 0.4615
# Epoch 21/45
# 1/1 [==============================] - 0s 184ms/step - loss: 1.0358 - accuracy: 0.5000 - precision: 0.7778 - recall: 0.5385
# Epoch 22/45
# 1/1 [==============================] - 0s 178ms/step - loss: 1.0880 - accuracy: 0.6250 - precision: 0.8182 - recall: 0.6923
# Epoch 23/45
# 1/1 [==============================] - 0s 175ms/step - loss: 0.6550 - accuracy: 0.5625 - precision: 0.8000 - recall: 0.6154
# Epoch 24/45
# 1/1 [==============================] - 0s 192ms/step - loss: 0.8812 - accuracy: 0.6250 - precision: 0.8889 - recall: 0.6154
# Epoch 25/45
# 1/1 [==============================] - 0s 191ms/step - loss: 0.8575 - accuracy: 0.5000 - precision: 0.8571 - recall: 0.4615
# Epoch 26/45
# 1/1 [==============================] - 0s 193ms/step - loss: 0.8537 - accuracy: 0.5625 - precision: 0.8000 - recall: 0.6154
# Epoch 27/45
# 1/1 [==============================] - 0s 193ms/step - loss: 0.7789 - accuracy: 0.5625 - precision: 0.8000 - recall: 0.6154
# Epoch 28/45
# 1/1 [==============================] - 0s 187ms/step - loss: 1.2116 - accuracy: 0.3750 - precision: 0.6667 - recall: 0.4615
# Epoch 29/45
# 1/1 [==============================] - 0s 189ms/step - loss: 0.9336 - accuracy: 0.5000 - precision: 0.7778 - recall: 0.5385
# Epoch 30/45
# 1/1 [==============================] - 0s 184ms/step - loss: 0.8139 - accuracy: 0.6875 - precision: 1.0000 - recall: 0.6154
# Epoch 31/45
# 1/1 [==============================] - 0s 182ms/step - loss: 1.1481 - accuracy: 0.4375 - precision: 0.7000 - recall: 0.5385
# Epoch 32/45
# 1/1 [==============================] - 0s 185ms/step - loss: 0.7153 - accuracy: 0.4375 - precision: 0.7500 - recall: 0.4615
# Epoch 33/45
# 1/1 [==============================] - 0s 186ms/step - loss: 0.7167 - accuracy: 0.6250 - precision: 0.8889 - recall: 0.6154
# Epoch 34/45
# 1/1 [==============================] - 0s 185ms/step - loss: 1.3984 - accuracy: 0.3750 - precision: 0.6667 - recall: 0.4615
# Epoch 35/45
# 1/1 [==============================] - 0s 176ms/step - loss: 0.5685 - accuracy: 0.6875 - precision: 0.9000 - recall: 0.6923
# Epoch 36/45
# 1/1 [==============================] - 0s 174ms/step - loss: 0.5890 - accuracy: 0.8125 - precision: 1.0000 - recall: 0.7692
# Epoch 37/45
# 1/1 [==============================] - 0s 179ms/step - loss: 0.8607 - accuracy: 0.5000 - precision: 0.7778 - recall: 0.5385
# Epoch 38/45
# 1/1 [==============================] - 0s 187ms/step - loss: 0.6171 - accuracy: 0.6875 - precision: 0.9000 - recall: 0.6923
# Epoch 39/45
# 1/1 [==============================] - 0s 186ms/step - loss: 0.7604 - accuracy: 0.6250 - precision: 0.8889 - recall: 0.6154
# Epoch 40/45
# 1/1 [==============================] - 0s 186ms/step - loss: 0.9830 - accuracy: 0.5000 - precision: 0.7778 - recall: 0.5385
# Epoch 41/45
# 1/1 [==============================] - 0s 175ms/step - loss: 0.7960 - accuracy: 0.5000 - precision: 0.8571 - recall: 0.4615
# Epoch 42/45
# 1/1 [==============================] - 0s 183ms/step - loss: 0.8273 - accuracy: 0.5625 - precision: 0.8750 - recall: 0.5385
# Epoch 43/45
# 1/1 [==============================] - 0s 190ms/step - loss: 1.0069 - accuracy: 0.5000 - precision: 0.7778 - recall: 0.5385
# Epoch 44/45
# 1/1 [==============================] - 0s 174ms/step - loss: 0.6326 - accuracy: 0.6250 - precision: 0.8182 - recall: 0.6923
# Epoch 45/45
# 1/1 [==============================] - 0s 183ms/step - loss: 0.7767 - accuracy: 0.4375 - precision: 0.7500 - recall: 0.4615

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 59s 195ms/step - loss: 0.7415 - accuracy: 0.6066 - precision: 0.8021 - recall: 0.6252 - val_loss: 1.0039 - val_accuracy: 0.7356 - val_precision: 0.7356 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 49s 188ms/step - loss: 0.3951 - accuracy: 0.8060 - precision: 0.9728 - recall: 0.7605 - val_loss: 1.2920 - val_accuracy: 0.7385 - val_precision: 0.7382 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 49s 190ms/step - loss: 0.3708 - accuracy: 0.8230 - precision: 0.9621 - recall: 0.7933 - val_loss: 2.8483 - val_accuracy: 0.2644 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 261/261 [==============================] - 50s 191ms/step - loss: 0.3055 - accuracy: 0.8681 - precision: 0.9719 - recall: 0.8469 - val_loss: 0.5867 - val_accuracy: 0.7865 - val_precision: 0.9982 - val_recall: 0.7115
# Epoch 5/25
# 261/261 [==============================] - 50s 193ms/step - loss: 0.3214 - accuracy: 0.8582 - precision: 0.9718 - recall: 0.8335 - val_loss: 1.1829 - val_accuracy: 0.6135 - val_precision: 1.0000 - val_recall: 0.4731
# Epoch 6/25
# 261/261 [==============================] - 52s 201ms/step - loss: 0.3000 - accuracy: 0.8705 - precision: 0.9749 - recall: 0.8480 - val_loss: 0.1795 - val_accuracy: 0.9308 - val_precision: 0.9638 - val_recall: 0.9411
# Epoch 7/25
# 261/261 [==============================] - 54s 208ms/step - loss: 0.3040 - accuracy: 0.8649 - precision: 0.9731 - recall: 0.8413 - val_loss: 0.6295 - val_accuracy: 0.7875 - val_precision: 0.9982 - val_recall: 0.7120
# Epoch 8/25
# 261/261 [==============================] - 48s 182ms/step - loss: 0.2834 - accuracy: 0.8719 - precision: 0.9756 - recall: 0.8492 - val_loss: 0.3288 - val_accuracy: 0.8712 - val_precision: 0.9937 - val_recall: 0.8303
# Epoch 9/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.2746 - accuracy: 0.8846 - precision: 0.9709 - recall: 0.8708 - val_loss: 0.1921 - val_accuracy: 0.9183 - val_precision: 0.9485 - val_recall: 0.9398
# Epoch 10/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.2771 - accuracy: 0.8822 - precision: 0.9739 - recall: 0.8649 - val_loss: 1.4521 - val_accuracy: 0.4413 - val_precision: 1.0000 - val_recall: 0.2395
# Epoch 11/25
# 261/261 [==============================] - 48s 185ms/step - loss: 0.2632 - accuracy: 0.8891 - precision: 0.9769 - recall: 0.8715 - val_loss: 1.2145 - val_accuracy: 0.5808 - val_precision: 1.0000 - val_recall: 0.4301
# Epoch 12/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.2676 - accuracy: 0.8827 - precision: 0.9733 - recall: 0.8663 - val_loss: 0.2652 - val_accuracy: 0.8933 - val_precision: 0.9808 - val_recall: 0.8716
# Epoch 13/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.2821 - accuracy: 0.8817 - precision: 0.9735 - recall: 0.8644 - val_loss: 1.3198 - val_accuracy: 0.5115 - val_precision: 1.0000 - val_recall: 0.3359
# Epoch 14/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.2731 - accuracy: 0.8805 - precision: 0.9677 - recall: 0.8683 - val_loss: 1.1823 - val_accuracy: 0.7500 - val_precision: 0.7463 - val_recall: 1.0000
# Epoch 15/25
# 261/261 [==============================] - 48s 183ms/step - loss: 0.2408 - accuracy: 0.8997 - precision: 0.9776 - recall: 0.8853 - val_loss: 0.2127 - val_accuracy: 0.9288 - val_precision: 0.9269 - val_recall: 0.9803
# Epoch 16/25
# 261/261 [==============================] - 48s 185ms/step - loss: 0.2794 - accuracy: 0.8714 - precision: 0.9721 - recall: 0.8517 - val_loss: 0.3207 - val_accuracy: 0.8663 - val_precision: 0.9984 - val_recall: 0.8194
# Epoch 17/25
# 261/261 [==============================] - 48s 183ms/step - loss: 0.2539 - accuracy: 0.8822 - precision: 0.9729 - recall: 0.8659 - val_loss: 0.2857 - val_accuracy: 0.9010 - val_precision: 0.9955 - val_recall: 0.8695
# Epoch 18/25
# 261/261 [==============================] - 48s 186ms/step - loss: 0.2679 - accuracy: 0.8865 - precision: 0.9702 - recall: 0.8735 - val_loss: 1.1349 - val_accuracy: 0.5846 - val_precision: 1.0000 - val_recall: 0.4353
# Epoch 19/25
# 261/261 [==============================] - 49s 187ms/step - loss: 0.2516 - accuracy: 0.8910 - precision: 0.9770 - recall: 0.8745 - val_loss: 0.1516 - val_accuracy: 0.9471 - val_precision: 0.9720 - val_recall: 0.9555
# Epoch 20/25
# 261/261 [==============================] - 48s 185ms/step - loss: 0.2545 - accuracy: 0.8932 - precision: 0.9739 - recall: 0.8797 - val_loss: 0.2581 - val_accuracy: 0.9067 - val_precision: 0.9926 - val_recall: 0.8796
# Epoch 21/25
# 261/261 [==============================] - 48s 186ms/step - loss: 0.2251 - accuracy: 0.9095 - precision: 0.9744 - recall: 0.9028 - val_loss: 0.1717 - val_accuracy: 0.9365 - val_precision: 0.9429 - val_recall: 0.9725
# Epoch 22/25
# 261/261 [==============================] - 48s 183ms/step - loss: 0.2412 - accuracy: 0.9045 - precision: 0.9773 - recall: 0.8917 - val_loss: 0.4754 - val_accuracy: 0.8365 - val_precision: 1.0000 - val_recall: 0.7775
# Epoch 23/25
# 261/261 [==============================] - 48s 183ms/step - loss: 0.2313 - accuracy: 0.9016 - precision: 0.9730 - recall: 0.8927 - val_loss: 0.4565 - val_accuracy: 0.8240 - val_precision: 0.8072 - val_recall: 1.0000
# Epoch 24/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.2178 - accuracy: 0.9068 - precision: 0.9774 - recall: 0.8951 - val_loss: 0.9241 - val_accuracy: 0.7106 - val_precision: 1.0000 - val_recall: 0.6060
# Epoch 25/25
# 261/261 [==============================] - 48s 185ms/step - loss: 0.2205 - accuracy: 0.9140 - precision: 0.9742 - recall: 0.9087 - val_loss: 0.1290 - val_accuracy: 0.9510 - val_precision: 0.9685 - val_recall: 0.9647

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 4s 102ms/step - loss: 1.0280 - accuracy: 0.7228 - precision: 0.7006 - recall: 0.9718
# Loss: 1.0279521942138672,
# Accuracy: 0.7227563858032227,
# Precision: 0.7005545496940613,
# Recall: 0.971794843673706

# %% [markdown]
# # 회고
# ### TPU 로 돌리려고 해보았으나, 자료형 (텐서형태로 입력되어야 함) 및 데이터 로드 과정에서 문제가 있었으며, 따라서 GPU 로 돌리게 되었다
# ### ImageDataGenerator 를 적절히 이용하여 model.fit 이전에 model.fit 을 시켰다. 그 결과 augmentation 이 잘 되었고 정확도가 올라가게 되었다. 그런데 어떤 기능은 쓰면 더 내려가는 경우가 있으므로
# ### 깊은 이해가 필요하다.
# ### False Positive(FP): 분류자가 부정 클래스를 긍정으로 잘못 예측한 예측의 수를 나타냅니다. 이것이 중요하므로, (TP+TN)/(TP+TN+FP+FN) 공식 인 accuracy 가 중요하다.
